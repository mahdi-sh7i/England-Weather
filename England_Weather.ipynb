# %% [markdown]
# # بخش اول

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# دیتاست مورد نظر ما اب و هوای کشور انگلیس هست. در این دیتاست بحث رطوبت را مورد بررسی قرار می دهیم. ابتدا دیتاست را فراخوانی نموده و در قالب یک دیتافرم به تاتغییرات داخل آن می پردازیم

# %%
data = pd.read_csv("/home/mahdi/telegram/S3E5/EnglandWeather.csv")
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             9.472222            14.1197               1015.13      0.89
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             9.472222            14.1197               1015.13      0.89
# ...

# %% [markdown]
#  یک دیتافرم مختص ستون ها (فیچر هایی) که غیر عددی هستند اختصاص می دهیم.

# %%
df2 = pd.DataFrame(data , columns = ["Summary","Precip Type"])
df2
# Out:
#              Summary Precip Type
# 0      Partly Cloudy        rain
# 1      Partly Cloudy        rain
# 2      Mostly Cloudy        rain
# 3      Partly Cloudy        rain
# 4      Mostly Cloudy        rain
# ...              ...         ...
# 96448  Partly Cloudy        rain
# 96449  Partly Cloudy        rain
# 96450  Partly Cloudy        rain
# 96451  Partly Cloudy        rain
# 96452  Partly Cloudy        rain
#
# [96453 rows x 2 columns]

# %% [markdown]
#  دیتافرم مختص ستون ها (فیچر هایی) که عددی هستند اختصاص می دهیم.

# %%
df3 = pd.DataFrame(data , columns = ["Temperature (C)","Wind Speed (km/h)" ,"Pressure (millibars)" ,"Humidity"])
df3
# Out:
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             9.472222            14.1197               1015.13      0.89
# 1             9.355556            14.2646               1015.63      0.86
# 2             9.377778             3.9284               1015.94      0.89
# 3             8.288889            14.1036               1016.41      0.83
# 4             8.755556            11.0446               1016.51      0.83
# ...                ...                ...                   ...       ...
# 96448        26.016667            10.9963               1014.36      0.43
# 96449        24.583333            10.0947               1015.16      0.48
# 96450        22.038889             8.9838               1015.66      0.56
# 96451        21.522222            10.5294               1015.95      0.60
# 96452        20.438889             5.8765               1016.16      0.61
#
# [96453 rows x 4 columns]

# %% [markdown]
# حال هر سه دیتا فریم را دراپنا می کنیم تا مقادیر میسنیگ ولیو نداشته باشیم

# %%
dfi = df.dropna()
df2i = df2.dropna()
df3i = df3.dropna()

# %% [markdown]
# 1. 96453 rows × 7 columns   >>    first
# 2. 95936 rows × 7 columns    >>    after dropna

# %%
dfi
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             9.472222            14.1197               1015.13      0.89
# ...

# %% [markdown]
# هر سه دیتا فرم را توصیف می کنیم. تا اطلاعات کلی نسبت به فیچر های عددی و غیر عددی پیدا کنیم

# %%
dfi.describe(include="all")
# Out:
#                        Formatted Date        Summary Precip Type  \
# count                           95936          95936       95936
# unique                          95912             27           2
# top     2010-08-02 08:00:00.000 +0200  Partly Cloudy        rain
# freq                                2          31635       85224
# mean                              NaN            NaN         NaN
# std                               NaN            NaN         NaN
# min                               NaN            NaN         NaN
# 25%                               NaN            NaN         NaN
# 50%                               NaN            NaN         NaN
# 75%                               NaN            NaN         NaN
# max                               NaN            NaN         NaN
#
#         Temperature (C)  Wind Speed (km/h)  Pressure (millibars)      Humidity
# count      95936.000000       95936.000000          95936.000000  95936.000000
# ...

# %% [markdown]
# 1. تعداد ستون ها در دیتاست اول با هم برابر است خیلی خوبه
# 2. Summary مقادیرش 27 نوع یونیک دارد
# 3. Precip Type دو نوع یونیک دارد

# %%
df2i.describe(include="all")
# Out:
#               Summary Precip Type
# count           95936       95936
# unique             27           2
# top     Partly Cloudy        rain
# freq            31635       85224

# %% [markdown]
# * Summary
#        1.     مقادیر یونیک 27 تا هست
#
#        2. Partly Cloudy  بیشترین سلول ها را به خود اختصاص داده
# * Precip Type
#       1.                  مقادیر یونیک کلا 2 تا است
#
#       2.       rain  بیشترین مقدار تکرار شونده را شامل می شده

# %%
df3i.describe(include="all")
# Out:
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)      Humidity
# count     96453.000000       96453.000000          96453.000000  96453.000000
# mean         11.932678          10.810640           1003.235956      0.734899
# std           9.551546           6.913571            116.969906      0.195473
# min         -21.822222           0.000000              0.000000      0.000000
# 25%           4.688889           5.828200           1011.900000      0.600000
# 50%          12.000000           9.965900           1016.450000      0.780000
# 75%          18.838889          14.135800           1021.090000      0.890000
# max          39.905556          63.852600           1046.380000      1.000000

# %% [markdown]
# توصیفی بر مقادیر عددی

# %%
# #####################################

# %%
plt.figure (figsize = (10, 10) , dpi = 120)
plt.scatter (dfi["Humidity"], dfi["Temperature (C)"])

plt.xlabel ('Humidity')
plt.ylabel ('Temperature (C)')

plt.grid()

# %% [markdown]
# # اثر پذیری دما بر رطوبت
# 1. برای داشتن رطوبت در مقدار نمونه بالا به دمایی بالای -10 درجه نباز مند هستیم
# 2. حداقل میران رطوبت 0.2 هست که از دمایی 10 تا 40 درجه این میزان رطوبت به اکثریت مقداری خود می رسد
# 3.  برای مقدار رطوبت 0.4 در مقدار موثر دمایی حداقل 0 و اکثریت دمایی 35 درجه را نیازمند هستیم
# 4. برای مقدار رطوبت 0.6 به حداقل میزان دمایی -10 درجه و حداکثر میزان دمایی 32 درجه نیاز مند هستیم
# 5.  برای مقدار رطوبت 0.8 به حداقل میزان دمایی -10 درجه و حداکثر میزان دمایی 32 درجه نیاز مند هستیم
# 6. ولی برای رطوبت حدود 1 مقدار دمایی باید از -10 در جه بالا تر باشد و حداکثر دمای 22 درجه را شاهد هستیم
#    * به صورت کلی باره دمایی در هر مقدار رطوبت مقدار حدود 30 درجه می باشد
#    * در رطوبت های مقادیر پایین مثلا 0.2 درجه این مقدار از 10 تا 40 و در مقادیر بالا تر رطوبت در همان بازه ولی پایین تر می آید مثلا رطوبت 0.6 بازه ای بین -10 تا 32 درجه می باشد
#    * با توجه به اینکه مقدار رطوبتی در 0.8 به منفی -20 درجه میرسد در مقدار رطوبت 1 در دمایی -10 در رطوبت مقدار حداقل دمایی بالا می رود
#    * حداکثر رطوبت بازه بین (0.6 - 1) مقدار دمایی بین 0 تا 22 درجه را شامل می شود

# %%
dfi.describe(include="all")
# Out:
#                        Formatted Date        Summary Precip Type  \
# count                           95936          95936       95936
# unique                          95912             27           2
# top     2010-08-02 08:00:00.000 +0200  Partly Cloudy        rain
# freq                                2          31635       85224
# mean                              NaN            NaN         NaN
# std                               NaN            NaN         NaN
# min                               NaN            NaN         NaN
# 25%                               NaN            NaN         NaN
# 50%                               NaN            NaN         NaN
# 75%                               NaN            NaN         NaN
# max                               NaN            NaN         NaN
#
#         Temperature (C)  Wind Speed (km/h)  Pressure (millibars)      Humidity
# count      95936.000000       95936.000000          95936.000000  95936.000000
# ...

# %%
plt.figure (figsize = (10, 10) , dpi = 120)
plt.scatter (dfi["Humidity"], dfi["Wind Speed (km/h)"])

plt.xlabel ('Humidity')
plt.ylabel ('Wind Speed (km/h)')

plt.grid()

# %% [markdown]
# # اثر پذیری سرعت باد بر رطوبت

# %% [markdown]
# * با توحه به شکل بالا حداقل میزان رطوب هوا حدود 0.2 می باشد
# * میزان رطوبت بین 0.4 - 0.8 تا مقادیر حدودی 30 تا 40 سرعت باد نیز پایداری خوبی دارد ولی از این مقدار بالا تر میزان این درجه ار رطوبت کم می شود
# * در مقادیر رطوبی 0.2 تا 0.4 و 0.8 تا 1 تاثیر سرعت باد از حدود 30 بسیار مشهود تر است
# *  مقدار روطوبت در سرعت های بالای باد بسیار کم تراکم شده است از حدود 37 به بالا

# %%
plt.figure (figsize = (12, 6) , dpi = 100)
plt.scatter (dfi["Humidity"], dfi["Pressure (millibars)"])

plt.xlabel ('Humidity')
plt.ylabel ('Pressure (millibars)')

plt.grid()

# %% [markdown]
# # اثر پذیری فشار هوا بر رطوبت
# * به حتمال زیاد قبل از این خروجی باید تغیییراتی روی دیتا انجام شود چون فشار 0 و 1000 فقط ثبت شده است دیتاست بر اساس فشار نیز مرتب شد و خروجی دقیقا مثل رسم بالا بود.
# * به صورت کلی ما مقادیر رطوبتی ثبت شدمون یا در فشار هوای صفر یا در فشار هوایی 1000 ثبت شده اند
# * در فشار هوای صفر مقادیر رطوبی بین 0.22 تا 1 با کمی گسستگی در نزدیک 1
# *  ولی در فشار حدود 1000 مقادیر رطوبتی از حدود 0.15 تا حدود 1 می باشد
# *  سمپل های ما در فشار حدود 1000 خیلی بیشتر مشاده می شود
# *  به احتمال زیاد مکان های نمونه برداری فقط دارای این دو نمونه فشار هوا بوده اند

# %%
plt.figure (figsize = (12, 6) , dpi = 100)
plt.scatter (dfi["Humidity"], dfi["Wind Speed (km/h)"])
plt.scatter (dfi["Humidity"], dfi["Temperature (C)"] , color = 'red')

plt.xlabel ('Humidity')
plt.ylabel ('Wind Speed & Temperature')

plt.grid()

# %% [markdown]
# # اثر پذیری باد و دما بر رطوبت
# * با توجه به شکل حداکثر دما حدود 40 و اکثریت سرعت هم حدود 40 هست برای اکثریت نمونه رطوبتی
# * با افزایش سرعت باد میزان دمایی محطی نیز کاهش یافته  تعداد سمپل های نمونه نیز کاهش یافته است

# %%
plt.figure (figsize = (12, 6) , dpi = 100)
plt.scatter (dfi["Humidity"], dfi["Summary"])

plt.xlabel ('Humidity')
plt.ylabel ('Summary')

plt.grid()

# %% [markdown]
# # مقدار ابر بر رطوبت
# - اگر تصویر را به صورت عمودی مورد بررسی قرار دهیم
#   1. در مقادیر پایین به خاطر وجود ایر مقدار روطوبت بیشتر است به جز مه آلود که از حدود 0.7 مقدار رطوبت را شامل می شود
#   2. به صورت کلی می توان به یک نتیجه حالت های رطوبتی مثل بارش باران ، حالت های ابری ، مه و امثالوهم مقادیر رطوبتی بالا تری را شامل می شوند

# %% [markdown]
# * ترتیب ستون عمودی
# باران
# نسیم و خشک
# خشک و عمدتاً ابری
# باد و خشک
# باران ریز و نمناک
# باران نور
# مرطوب و ابری
# بادی
# خشک
# باد خطرناک و نیمه ابری
# وزش باد و عمدتاً ابری
# خشک و نیمه ابری
# نسیم
# وزش باد و نیمه ابری
# نسیم و مه آلود
# باد و ابری
# باد و مه آلود
# مرطوب و نیمه ابری
# مرطوب و عمدتا ابری
# نسیم و ابری
# وزش باد و نیمه ابری
# پاک کردن
# وزش باد و عمدتاً ابری
# مه آلود
# ابری
# اکثرا ابری
# نیمه ابری

# %%
plt.figure (figsize = (12, 6) , dpi = 100)
plt.scatter (dfi["Humidity"], dfi["Precip Type"])

plt.xlabel ('Humidity')
plt.ylabel ('Summary')

plt.grid()

# %% [markdown]
# # اثر پذیری باران و برف در رطوبت
# 1. به صورت کلی سطح رطوبتی که برف دارد از باران بیشتر است به گونه ای که باران از مقدار تقریبی 0.1 شروع ولی برف از 0.4 شروع می کند به سمت بالا رفتن
# 2. حداقل رطوبت مورد نیاز باران 0.1 به بالا ولی در مواردی مشاهده شده که برف در روطوبت های  پایین تر از 0.4 نیز بارش داشته بین 0.2 تا 0.4

# %%
plt.figure (figsize = (12, 6) , dpi = 100)
plt.scatter (dfi["Summary"], dfi["Precip Type"])

plt.xlabel ('Humidity')
plt.xticks(rotation = 90)
plt.ylabel ('Summary')

plt.grid()

# %% [markdown]
# # اثر پذیری نوع تراکم ابری بر بارش برف یا باران
# * با توجه به رسم بالا می توان متوجه شد که در تمامی تراکم های مشاهد بارش باران بوده ایم ولی فقط در 12 نوع تراکم می توانیم داشته باشیم برای بارش برف

# %%
plt.figure (figsize = (12, 6) , dpi = 100)
plt.scatter (dfi["Summary"], dfi["Temperature (C)"])

plt.xlabel ('Summary')
plt.xticks(rotation = 90)
plt.ylabel ('Temperature (C)')

plt.grid()

# %% [markdown]
# # تراکم ابری و دما
# * از رسم بالا می توان نتیجه گرفت که در هر تراکم ابری در آسمان ما باید چه انتظاری از دما داشته باشیم
# * مثلا در زمان تراکم هوایی که باعث بارش باران می شود دما در محدوده 2.5- تا 2.5+ می باشد
# * خشک و نیمه ابری بین 20 تا 40 درجه
# * و نیمه ابری در تمامی رنج هایی دمایی -20 تا +40 مشاهده شده است

# %%
plt.figure (figsize = (12, 6) , dpi = 100)
plt.scatter (dfi["Precip Type"], dfi["Temperature (C)"])

plt.xlabel ('Precip Type')
plt.ylabel ('Temperature (C)')

plt.grid()

# %% [markdown]
# # اثر پذیری دما بر بارش برف یا باران
# * رسم بالا بسیار ملموس لمس می شود به گونه ای که در بازه دمایی بین 0 تا 40 درجه شاهد بارش باران هستیم و در بازه دمایی 0 تا 20- شاهد بارش برف هستیم

# %%
dfi
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             9.472222            14.1197               1015.13      0.89
# ...

# %% [markdown]
# * برای تحلیل یا آنالیز قسمت زمانی یک دیتافرم جدید به نام ایجاد می کنیم : dfj
# **- دیتافریم را بر اساس تاریخ مرتب می کنیم -**

# %%
dfj = df.dropna()
dfj = dfj.sort_values(by = "Formatted Date" )
dfj
# Out:
#                       Formatted Date        Summary Precip Type  \
# 2880   2006-01-01 00:00:00.000 +0100  Partly Cloudy        rain
# 2881   2006-01-01 01:00:00.000 +0100  Mostly Cloudy        rain
# 2882   2006-01-01 02:00:00.000 +0100  Mostly Cloudy        rain
# 2883   2006-01-01 03:00:00.000 +0100       Overcast        rain
# 2884   2006-01-01 04:00:00.000 +0100  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 89728  2016-12-31 19:00:00.000 +0100  Mostly Cloudy        rain
# 89729  2016-12-31 20:00:00.000 +0100  Mostly Cloudy        rain
# 89730  2016-12-31 21:00:00.000 +0100  Mostly Cloudy        snow
# 89731  2016-12-31 22:00:00.000 +0100  Mostly Cloudy        snow
# 89732  2016-12-31 23:00:00.000 +0100  Mostly Cloudy        snow
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 2880          0.577778            17.1143               1016.66      0.89
# ...

# %% [markdown]
# * Formatted Date type is object i want to change datetime64[ns, UTC]

# %% [markdown]
# * اطلاعات دیتا فریم

# %%
dfj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95936 entries, 2880 to 89732
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Formatted Date        95936 non-null  object
#  1   Summary               95936 non-null  object
#  2   Precip Type           95936 non-null  object
#  3   Temperature (C)       95936 non-null  float64
#  4   Wind Speed (km/h)     95936 non-null  float64
#  5   Pressure (millibars)  95936 non-null  float64
#  6   Humidity              95936 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 5.9+ MB

# %% [markdown]
# * با استفاده از دستور زیر تایپ ستون مورد نظر را تغییر می دهیم

# %%
dfj ['Formatted Date'] = pd.to_datetime(dfj ['Formatted Date'], utc=True)
dfj
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 2880  2005-12-31 23:00:00+00:00  Partly Cloudy        rain         0.577778
# 2881  2006-01-01 00:00:00+00:00  Mostly Cloudy        rain         1.161111
# 2882  2006-01-01 01:00:00+00:00  Mostly Cloudy        rain         1.666667
# 2883  2006-01-01 02:00:00+00:00       Overcast        rain         1.711111
# 2884  2006-01-01 03:00:00+00:00  Mostly Cloudy        rain         1.183333
# ...                         ...            ...         ...              ...
# 89728 2016-12-31 18:00:00+00:00  Mostly Cloudy        rain         0.488889
# 89729 2016-12-31 19:00:00+00:00  Mostly Cloudy        rain         0.072222
# 89730 2016-12-31 20:00:00+00:00  Mostly Cloudy        snow        -0.233333
# 89731 2016-12-31 21:00:00+00:00  Mostly Cloudy        snow        -0.472222
# 89732 2016-12-31 22:00:00+00:00  Mostly Cloudy        snow        -0.677778
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# ...

# %% [markdown]
# * تایپ ستون مورد نظر تغییر پیدا کرد
# * type change to datetime64[ns, UTC]

# %%
dfj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95936 entries, 2880 to 89732
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Formatted Date        95936 non-null  datetime64[ns, UTC]
#  1   Summary               95936 non-null  object
#  2   Precip Type           95936 non-null  object
#  3   Temperature (C)       95936 non-null  float64
#  4   Wind Speed (km/h)     95936 non-null  float64
#  5   Pressure (millibars)  95936 non-null  float64
#  6   Humidity              95936 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(4), object(2)
# memory usage: 5.9+ MB

# %% [markdown]
# * با استفاده از دستور زیر سال - ماه و روز را به صورت جداگانه استخراج می کنیم

# %%
dfj ["year"] = dfj['Formatted Date'].dt.year
dfj ["month"] = dfj ['Formatted Date'].dt.month
dfj ["day"] = dfj ['Formatted Date'].dt.day
dfj
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 2880  2005-12-31 23:00:00+00:00  Partly Cloudy        rain         0.577778
# 2881  2006-01-01 00:00:00+00:00  Mostly Cloudy        rain         1.161111
# 2882  2006-01-01 01:00:00+00:00  Mostly Cloudy        rain         1.666667
# 2883  2006-01-01 02:00:00+00:00       Overcast        rain         1.711111
# 2884  2006-01-01 03:00:00+00:00  Mostly Cloudy        rain         1.183333
# ...                         ...            ...         ...              ...
# 89728 2016-12-31 18:00:00+00:00  Mostly Cloudy        rain         0.488889
# 89729 2016-12-31 19:00:00+00:00  Mostly Cloudy        rain         0.072222
# 89730 2016-12-31 20:00:00+00:00  Mostly Cloudy        snow        -0.233333
# 89731 2016-12-31 21:00:00+00:00  Mostly Cloudy        snow        -0.472222
# 89732 2016-12-31 22:00:00+00:00  Mostly Cloudy        snow        -0.677778
#
# ...

# %% [markdown]
# * کتاب خانه فراخوانی شده

# %%
import datetime

# %% [markdown]
# *  یک ستون واحد می خواهیم برای تاریخ
# * با استفاده از دستور زیر دوباره یک ستون پیوسته از سال ماه و روز درست می کنیم
# * با استفاده از همان دستورات متغییری دیگر تعریف می کنیم تا بعد به جدول اضافه کنیم

# %%
dfj ["time"] = dfj ['year'].astype(str) + '-' + dfj ['month'].astype(str) + '-' + dfj ['day'].astype(str)
time = dfj ['year'].astype(str) + '-' + dfj ['month'].astype(str) + '-' + dfj ['day'].astype(str)
dfj
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 2880  2005-12-31 23:00:00+00:00  Partly Cloudy        rain         0.577778
# 2881  2006-01-01 00:00:00+00:00  Mostly Cloudy        rain         1.161111
# 2882  2006-01-01 01:00:00+00:00  Mostly Cloudy        rain         1.666667
# 2883  2006-01-01 02:00:00+00:00       Overcast        rain         1.711111
# 2884  2006-01-01 03:00:00+00:00  Mostly Cloudy        rain         1.183333
# ...                         ...            ...         ...              ...
# 89728 2016-12-31 18:00:00+00:00  Mostly Cloudy        rain         0.488889
# 89729 2016-12-31 19:00:00+00:00  Mostly Cloudy        rain         0.072222
# 89730 2016-12-31 20:00:00+00:00  Mostly Cloudy        snow        -0.233333
# 89731 2016-12-31 21:00:00+00:00  Mostly Cloudy        snow        -0.472222
# 89732 2016-12-31 22:00:00+00:00  Mostly Cloudy        snow        -0.677778
#
# ...

# %% [markdown]
# **- دیتافریم را بر اساس تاریخ مرتب می کنیم -**

# %% [markdown]
# * چند متغیر تعریف می کنم
# * ستون های اضافی را خارج می کنم و فقط ستون زمان را به دیتافرم اضافه می کنم

# %%
dfj = dfj.drop(columns = ["Formatted Date", "year","month","day","time"])

# %%
dfj
# Out:
#              Summary Precip Type  Temperature (C)  Wind Speed (km/h)  \
# 2880   Partly Cloudy        rain         0.577778            17.1143
# 2881   Mostly Cloudy        rain         1.161111            16.6152
# 2882   Mostly Cloudy        rain         1.666667            20.2538
# 2883        Overcast        rain         1.711111            14.4900
# 2884   Mostly Cloudy        rain         1.183333            13.9426
# ...              ...         ...              ...                ...
# 89728  Mostly Cloudy        rain         0.488889             9.7566
# 89729  Mostly Cloudy        rain         0.072222             9.4185
# 89730  Mostly Cloudy        snow        -0.233333             9.2736
# 89731  Mostly Cloudy        snow        -0.472222             9.2414
# 89732  Mostly Cloudy        snow        -0.677778             9.2253
#
#        Pressure (millibars)  Humidity
# 2880                1016.66      0.89
# 2881                1016.15      0.85
# ...

# %% [markdown]
# * گرفتن یک دیتا فریم  برای   groupby
# * اضافه کردن زمان به دیتا فریم

# %%
dfj.insert(0 , "Time" , time  , True )
dfx = dfj
dfx
# Out:
#              Time        Summary Precip Type  Temperature (C)  \
# 2880   2005-12-31  Partly Cloudy        rain         0.577778
# 2881     2006-1-1  Mostly Cloudy        rain         1.161111
# 2882     2006-1-1  Mostly Cloudy        rain         1.666667
# 2883     2006-1-1       Overcast        rain         1.711111
# 2884     2006-1-1  Mostly Cloudy        rain         1.183333
# ...           ...            ...         ...              ...
# 89728  2016-12-31  Mostly Cloudy        rain         0.488889
# 89729  2016-12-31  Mostly Cloudy        rain         0.072222
# 89730  2016-12-31  Mostly Cloudy        snow        -0.233333
# 89731  2016-12-31  Mostly Cloudy        snow        -0.472222
# 89732  2016-12-31  Mostly Cloudy        snow        -0.677778
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 2880             17.1143               1016.66      0.89
# 2881             16.6152               1016.15      0.85
# ...

# %%
dfx
# Out:
#              Time        Summary Precip Type  Temperature (C)  \
# 2880   2005-12-31  Partly Cloudy        rain         0.577778
# 2881     2006-1-1  Mostly Cloudy        rain         1.161111
# 2882     2006-1-1  Mostly Cloudy        rain         1.666667
# 2883     2006-1-1       Overcast        rain         1.711111
# 2884     2006-1-1  Mostly Cloudy        rain         1.183333
# ...           ...            ...         ...              ...
# 89728  2016-12-31  Mostly Cloudy        rain         0.488889
# 89729  2016-12-31  Mostly Cloudy        rain         0.072222
# 89730  2016-12-31  Mostly Cloudy        snow        -0.233333
# 89731  2016-12-31  Mostly Cloudy        snow        -0.472222
# 89732  2016-12-31  Mostly Cloudy        snow        -0.677778
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 2880             17.1143               1016.66      0.89
# 2881             16.6152               1016.15      0.85
# ...

# %%
dfx.dtypes
# Out:
# Time                     object
# Summary                  object
# Precip Type              object
# Temperature (C)         float64
# Wind Speed (km/h)       float64
# Pressure (millibars)    float64
# Humidity                float64
# dtype: object

# %% [markdown]
# * با استفاده از گروپ بای روی تایم
# * تعداد سطر ها 95936 به  4009 کاهش یافت
# * mean روی گروپ بای خطا میداد از sum استفاده کردم

# %%
dfx.groupby(['Time']).sum()
# Out:
#                                                       Summary  \
# Time
# 2005-12-31                                      Partly Cloudy
# 2006-1-1    Mostly CloudyMostly CloudyOvercastMostly Cloud...
# 2006-1-10   Partly CloudyOvercastMostly CloudyMostly Cloud...
# 2006-1-11   FoggyFoggyFoggyFoggyClearClearMostly CloudyMos...
# 2006-1-12   FoggyFoggyFoggyFoggyMostly CloudyMostly Cloudy...
# ...                                                       ...
# 2016-9-5    Partly CloudyMostly CloudyMostly CloudyMostly ...
# 2016-9-6    ClearPartly CloudyPartly CloudyPartly CloudyMo...
# 2016-9-7    Mostly CloudyMostly CloudyMostly CloudyMostly ...
# 2016-9-8    Partly CloudyPartly CloudyPartly CloudyMostly ...
# 2016-9-9    ClearClearClearClearClearClearPartly CloudyPar...
#
#                                                   Precip Type  \
# Time
# 2005-12-31                                               rain
# 2006-1-1    rainrainrainrainrainrainrainrainrainrainrainra...
# ...

# %% [markdown]
# * mean  در دستور پایین خروجی نداد

# %%
dfx.groupby(['Time']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
# ...

# %% [markdown]
# # تعداد نمونه برداری در هر سال
# * شمارش تعداد دیتا در هر سال
# * اگر تعداد سمپل ها در هر سال را جمع کنیم برابر است با تعداد کل دیتا ها
# *    سال شروع نمونه برداری برابر است 2005 اما تعدا سمپل ها بسیار بسیار کم است چون شروع نمونه برداری از 2005-12-31 است
# * از سال 2006 به بعد تعداد سمپل ها از 8000 تا بالا تر  است در سال 2012 کمی مفدار نمونه برداری کمتر بوده و در سال 2016 نیز انگار تا پایان سال  نمونه برداری انجام نشده است
# * در تمامی سال ها بجز سال 2005 تعداد سمپل ها حدود 9000 در هر سال می باشد

# %%
Year = pd.to_datetime (dfj.Time).dt.year
plt.title ('Nice of rows per year')  # count time serie
sns.countplot (x = Year)
# Out:
# <Axes: title={'center': 'Nice of rows per year'}, xlabel='Time', ylabel='count'>
